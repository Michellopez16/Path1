# %%
# %notebook inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Gráfica las siguiente ecuaciones

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Genera la siguiente grafica

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Diseña un algoritmo de búsqueda que encuentra la ruta más corta entre dos puntos

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !open .
